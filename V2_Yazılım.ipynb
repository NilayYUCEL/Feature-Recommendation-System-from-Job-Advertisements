# %%
import pandas as pd
import re
import os
import warnings
warnings.filterwarnings('ignore')

#pd.set_option('display.max_rows', 500)

# %% [markdown]
# ### Zemberek

# %%
import jpype

# %%
libjvmpath = "C:\Program Files\Java\jre1.8.0_341\\bin\server\jvm.dll"
jar = r"C:\Users\yucel\Desktop\staj\JupiterLab\zemberek\zemberek-full.jar"

# %%
if not jpype.isJVMStarted():
    jpype.startJVM(jvmpath=libjvmpath, classpath=jar)

# %%
TurkishMorphology = jpype.JClass('zemberek.morphology.TurkishMorphology')
morphology = TurkishMorphology.createWithDefaults()

# %%
LanguageIdentifier = jpype.JClass('zemberek.langid.LanguageIdentifier')
lid = LanguageIdentifier.fromInternalModels();

# %% [markdown]
# # STEMMING / STEP 7

# %% [markdown]
# Kelimeleri köke indirgeme işlemi

# %% [markdown]
# ## READ FILE

# %%
sentences = pd.read_csv("yazilim_uzmani_sentences_v2.csv")
sentences = sentences.drop(["Unnamed: 0"],axis=1)
sentences.reset_index(inplace=True)
sentences = sentences.drop(["index"],axis=1)
stem_sentences=sentences.copy()
stem_sentences.head()
# Out:
#   PostId                                           Sentence Language
# 0  Post0                dünyada ülkede, farklı dil yaklaşık   Türkçe
# 1  Post0  firma kullanılan erp yazılımı SPCL38SPCL busin...   Türkçe
# 2  Post0         üniversitelerin lisans bölümlerinden mezun   Türkçe
# 3  Post0   erp pojelerinde test uzmanı olarak yıl tecrübeli   Türkçe
# 4  Post0        analitik matematiksel düşünme yönü kuvvetli   Türkçe

# %% [markdown]
# ## STEMMING FUNCTIONS

# %% [markdown]
# ### Turkish

# %%
def stemming_turkish(text):
    deneme=""
    stem_text=""
    analysis: jpype.java.util.ArrayList = (
    morphology.analyzeAndDisambiguate(text).bestAnalysis()
    )
    for i in analysis:
        #print(i)
        if "UNK" in  str(i.getLemmas()[0]):
            stem_text=stem_text+" "+str(i.getStem())
            deneme = deneme + " "+str(i.getLemmas()[0])+str(i.getEnding())
        elif "Verb" in  str(i) or "Punc" in  str(i) :
            stem_text=stem_text+" "+str(i.getLemmas()[0])
        else:
            stem_text=stem_text+" "+str(i.getLemmas()[0])
            deneme = deneme + " "+str(i.getLemmas()[0])+str(i.getEnding())
    return stem_text

# %%
stemming_turkish("lise mezunuysanız")
# Out:
# ' lise mezun'

# %%
stem_sentences["Sentence"]=stem_sentences["Sentence"].apply(lambda text: stemming_turkish(str(text)))

# %%
#stem_sentences["Sentence"]=stem_sentences["Sentence"].replace(to_replace=[","],value=" ",regex=True,inplace=False)
#stem_sentences["Sentence"] = stem_sentences["Sentence"].apply(lambda text: text.strip())

# %%
stem_sentences["Sentence"].head(60)
# Out:
# 0                        dünya ülke , fark dil yaklaşık
# 1      firma kullan erp yazılım SPCL38SPCL business ...
# 2                         üniversite lisans bölüm mezun
# 3             erp pojelerinde test uzman ol yıl tecrübe
# 4                   analitik matematik düşün yön kuvvet
# 5                                      detay odak çalış
# 6                                           raporla yap
# 7                                       ekip çalış uyum
# 8                             problem çöz yetenek sahip
# 9                        i̇ş teslim tarih uyan i̇ş tani
# 10     program gereksinim karşıla emin , yeni yazılı...
# 11     bulun hata tür sorun çöz at adım özetle rapor...
# 12     hata potansiyel tanımla , risk değerlendir ye...
# 13                    yazılım test metodojilerine hakim
# 14                                   genel ni̇teli̇kler
# 15     üniversite , bilgisayar mühendis , yazılım mü...
# 16     yıl yazılım geliş deneyim yazılım geliş deney...
# 17     SPCL70SPCL , SPCL43SPCL , SPCL45SPCL core , e...
# 18     SPCL20SPCL , SPCL24SPCL script , jquery , ang...
# 19                web servis entegrasyon konu tecrübe ,
# 20     ms sql server veri taban biri programla deney...
# 21               nesne yönelim programla konu tecrübe ,
# 22             kod güvenlik kodla standart konu bilgi ,
# 23      analitik düşün , çözüm odak , öğren yeni açık ,
# 24                                  takım çalış yatkı ,
# 25     erkek aday asker tamamla yıl ertele , i̇ş tan...
# 26     oyun geliş oyna hayat felsefe dönüş genç dina...
# 27     ekip bünye yer al iste aşağı özellik sahip ba...
# 28     SPCL21SPCL 3d oyun geliş konu yıl tecrübe ref...
# 29                       SPCL70SPCL programla dil hakim
# 30                       yazılı mimari oop konu tecrübe
# 31                               üniversite bölüm mezun
# 32                 mobil oyun optimizasyon standart bil
# 33                              yaratı pratik çözüm sun
# 34                                   takım çalış yatkın
# 35                           i̇yi derece i̇ngilizce bil
# 36                  asker ilişki bulun erkek aday i̇çin
# 37                       eş zaman birden proje görev al
# 38           proje fikir kat , problem yaratı çözüm sun
# 39     oyun oyna sev , oyun geliş heves genç dinamik...
# 40                i̇ş tani firma geliş mobil oyun proje
# 41                               yazılım geliş yer al ,
# 42                     tasarım test süreç katkı sağla ,
# 43                      ekip arkadaş uyum içeri çalış ,
# 44                     yaratı fikir gelecek proje şekil
# 45     şirket görev aşağı nitelik sahip takım arkada...
# 46     üniversite bilgisayar , elektronik , matemati...
# 47                    yıl yazılım geliş tecrübe sahip ,
# 48     i̇yi derece SPCL43SPCL , SPCL35SPCL core , SP...
# 49       rest full , entity framework teknoloji hakim ,
# 50     SPCL20SPCL , js , jquery , css , bootstrap , ...
# 51     object oriented programla oop konu katman mim...
# 52                    mssql oracle veri taban deneyim ,
# 53          tercihen c SPCL71SPCL embedded tecrübe ol ,
# 54     tercihen linux işletim sistem uygula geliştir...
# 55            i̇yi derece i̇ngilizce bil aktif kullan ,
# 56       erkek aday asker tamamla yıl tecil , i̇ş tanım
# 57     banka baş sektör kuruluş geliş öde sistem yaz...
# 58     yazılım geliş proje aktif yer al deneyim sahip ,
# 59     tercihen proje yönetim iş analiz bilgi tecrüb...
# Name: Sentence, dtype: object

# %% [markdown]
# # CLEANING MEANINGFUL EXPRESSIONS / STEP 8

# %%
meaningless_frequent_sentences_raw = pd.read_fwf(os.path.abspath('..')+"/Data/eliminated_frequent_sentence.txt")
meaningless_frequent_sentences= meaningless_frequent_sentences_raw["Sentences"].apply(lambda text: text.strip())
meaningless_frequent_sentences = meaningless_frequent_sentences.tolist()

# %%
meaningless_frequent_sentences
# Out:
# ['i̇ş tani',
#  'go',
#  '"',
#  'ş',
#  'genel ni̇teli̇kler',
#  'genel nitelik',
#  'deneyelimli',
#  'i̇ş tan',
#  'ara nitelik',
#  'a',
#  'bölüm mezun',
#  'b',
#  'genel ni̇teli̇kler i̇ş tani',
#  'tic',
#  'yıl deneyim',
#  'kelime ifade et ses kal güç var ruh',
#  'muhteşem akustik yap değer zaman sahip çık',
#  'i̇şte ruh kendi hayran bırak',
#  'yıl tecrübe',
#  'yaş aş',
#  'i̇stanbul avrupa yaka ikamet et',
#  'ara ni̇teli̇kler',
#  'görev tanım',
#  'mi',
#  's',
#  'i̇şi̇n tani',
#  'alan yıl deneyim',
#  'benzer pozisyon yıl deneyim',
#  'i̇stanbul anadol yaka ikamet et',
#  'tarih no lisans sahip özel istihdam büro',
#  'alan yıl tecrübe',
#  'i̇şin tan',
#  'm',
#  'zaman haydi cesaret , iş duy heyecan , coşku büyük ritm parça ol , yeni yol keşfet , yolcu biz birlikte ritim tut , ezber boz ritim güç güç kat mı perakende hareket yapı ilgi',
#  'biz penti fark tını güç al ritm birlikte ayak uy',
#  'i̇stenen yetenek uzman',
#  'yıl deneyim',
#  'ltd',
#  'yıl tecrübe',
#  'şti',
#  'i̇stanbul avrupa yaka ikamet et',
#  'bölüm mezun',
#  'ara özellik',
#  'alan yıl deneyim sahip',
#  'yaş aralık',
#  'o',
#  'c',
#  'penti fark tını güç al ritm birlikte ayak uy',
#  'avrupa yaka ikamet et',
#  'yaş aş',
#  'çalış arkadaş ara',
#  'tarih numara izin belge faaliyet göster',
#  'i̇stanbul anadol yaka ikamet et',
#  'g',
#  'qualifications',
#  'takım arkadaş ara',
#  'ni̇teli̇kler',
#  'y',
#  'nitelik',
#  'üzeri kişi iş imkan sağla',
#  'ni',
#  'gün',
#  'iss özel kıl var',
#  'ankara ikamet et',
#  'i̇stanbul ikamet et',
#  'li',
#  'çeyrek asır medical park sağlık yolcu başla grup , liv hospital vm medical park hastane marka hizmet ver',
#  'sağlık uluslararası standart , uzman hekim kadro , has odak üst hizmet anlayış benimse mlpcare sağlık grub , joint commission international j akreditasyon belge sahip hastane',
#  'görev tani',
#  'mlpcare sağlık grub , i̇çin sağlık , hayat güzel değer kat hizmet felsefe hizmet ver hastane sağlık yolcu hız kes devam et',
#  'yaş ara',
#  'san',
#  'pozisyon kısa görev tanım uygun aday taşı gerek özellik aşağı yer al',
#  'fazla müşteri , nokta temiz , güvenlik , teknik bakım , catering , çamaşırhane yönetim , bitki bakım haşere kontrol destek hizmet hizmet sun sektör lider konum büyü devam et',
#  'fazla kişi istihdam sağla',
#  'rol sorumluluk',
#  'aynı zaman marka birlikte türkiye emek yurtiçi yurtdışı gurur temsil et',
#  'adecco grup , merkez i̇sviçre fazla ülke bölge yaklaşık',
#  'adil işık group ol adl love my body marka oluş marka kimlik değer türkiye dünya ülke yakın seçkin sat nokta ürün moda sever sun']

# %%
def clean_frequent_expression(text):
    for exp in meaningless_frequent_sentences:
        text=text.replace(" "+exp+" "," ")
    return  text

# %%
stem_sentences["Sentence"][46]
# Out:
# ' üniversite bilgisayar , elektronik , matematik mühendis bölüm mezun ,'

# %%
stem_sentences["Sentence"]=stem_sentences["Sentence"].apply(lambda text: " "+text+" ")

# %%
stem_sentences["Sentence"]=stem_sentences["Sentence"].apply(lambda text: clean_frequent_expression(text))

# %%
stem_sentences["Sentence"][46]
# Out:
# '  üniversite bilgisayar , elektronik , matematik mühendis , '

# %%
stem_sentences["Sentence"]=stem_sentences["Sentence"].apply(lambda text : re.sub('i', 'i', text))

# %% [markdown]
# # CREATE NEW SKILLS DF WITH SPLIT (",")/ STEP 9

# %%
sentences_split = pd.DataFrame(columns=['PostId','SentenceId' ,'Skill'])

# %%
stem_sentences["Sentence"]=stem_sentences["Sentence"].apply(lambda text: re.split(",",str(text)))

# %%
stem_sentences["Sentence"][3]
# Out:
# ['  erp pojelerinde test uzman ol ']

# %%
stem_sentences=stem_sentences.reset_index()

# %%
stem_sentences = stem_sentences.drop("index",axis=1)

# %%
stem_sentences
# Out:
#          PostId                                           Sentence Language
# 0         Post0               [  dünya ülke ,  fark dil yaklaşık ]   Türkçe
# 1         Post0  [  firma kullan erp yazılım SPCL38SPCL busines...   Türkçe
# 2         Post0                             [  üniversite lisans ]   Türkçe
# 3         Post0                 [  erp pojelerinde test uzman ol ]   Türkçe
# 4         Post0           [  analitik matematik düşün yön kuvvet ]   Türkçe
# ...         ...                                                ...      ...
# 14266  Post1119  [  üniversite lisans program biri mezun ,  ter...   Türkçe
# 14267  Post1119        [  sözlü yazılı i̇ngilizce bilgi sahip ,  ]   Türkçe
# 14268  Post1119                   [  erkek aday asker tamamla ,  ]   Türkçe
# 14269  Post1119  [  analitik düşün ,  sorumluluk üstlen ,  deta...   Türkçe
# 14270  Post1119  [  ekip çalış yatkın ,  araştır disiplin çalış...   Türkçe
#
# [14271 rows x 3 columns]

# %%
for i in range(len(stem_sentences)):
    for j in range (len(stem_sentences["Sentence"][i])):
        sentences_split.loc[len(sentences_split.index)] = [stem_sentences["PostId"][i], "Sentence"+str(i), stem_sentences["Sentence"][i][j]] 
sentences_split.head()
# Out:
#   PostId SentenceId                                              Skill
# 0  Post0  Sentence0                                        dünya ülke
# 1  Post0  Sentence0                                 fark dil yaklaşık
# 2  Post0  Sentence1    firma kullan erp yazılım SPCL38SPCL business...
# 3  Post0  Sentence2                                 üniversite lisans
# 4  Post0  Sentence3                     erp pojelerinde test uzman ol

# %%
sentences_split.drop(sentences_split[sentences_split['Skill'] == " "].index, inplace = True)

# %%
sentences_split.drop(sentences_split[sentences_split['Skill'] == ""].index, inplace = True)
sentences_split.reset_index(inplace=True)

# %%
sentences_split.head(60)
# Out:
#     index PostId  SentenceId  \
# 0       0  Post0   Sentence0
# 1       1  Post0   Sentence0
# 2       2  Post0   Sentence1
# 3       3  Post0   Sentence2
# 4       4  Post0   Sentence3
# 5       5  Post0   Sentence4
# 6       6  Post0   Sentence5
# 7       7  Post0   Sentence6
# 8       8  Post0   Sentence7
# 9       9  Post0   Sentence8
# 10     10  Post0   Sentence9
# 11     11  Post0  Sentence10
# 12     12  Post0  Sentence10
# 13     13  Post0  Sentence11
# 14     14  Post0  Sentence12
# 15     15  Post0  Sentence12
# 16     16  Post0  Sentence12
# 17     17  Post0  Sentence13
# 18     18  Post1  Sentence14
# 19     19  Post1  Sentence15
# 20     20  Post1  Sentence15
# 21     21  Post1  Sentence15
# 22     23  Post1  Sentence16
# 23     25  Post1  Sentence17
# 24     26  Post1  Sentence17
# 25     27  Post1  Sentence17
# 26     28  Post1  Sentence17
# 27     29  Post1  Sentence17
# 28     30  Post1  Sentence17
# 29     31  Post1  Sentence17
# 30     32  Post1  Sentence17
# 31     33  Post1  Sentence17
# 32     35  Post1  Sentence18
# 33     36  Post1  Sentence18
# 34     37  Post1  Sentence18
# 35     38  Post1  Sentence18
# 36     39  Post1  Sentence18
# 37     41  Post1  Sentence19
# 38     43  Post1  Sentence20
# 39     45  Post1  Sentence21
# 40     47  Post1  Sentence22
# 41     49  Post1  Sentence23
# 42     50  Post1  Sentence23
# 43     51  Post1  Sentence23
# 44     53  Post1  Sentence24
# 45     55  Post1  Sentence25
# 46     56  Post1  Sentence25
# 47     57  Post2  Sentence26
# 48     58  Post2  Sentence27
# 49     59  Post2  Sentence28
# 50     60  Post2  Sentence29
# 51     61  Post2  Sentence30
# 52     62  Post2  Sentence31
# 53     63  Post2  Sentence32
# 54     64  Post2  Sentence33
# 55     65  Post2  Sentence34
# 56     66  Post2  Sentence35
# 57     67  Post2  Sentence36
# 58     68  Post2  Sentence37
# 59     69  Post2  Sentence38
#
#                                                 Skill
# 0                                         dünya ülke
# 1                                  fark dil yaklaşık
# 2     firma kullan erp yazılım SPCL38SPCL business...
# 3                                  üniversite lisans
# 4                      erp pojelerinde test uzman ol
# 5                analitik matematik düşün yön kuvvet
# 6                                   detay odak çalış
# 7                                        raporla yap
# 8                                    ekip çalış uyum
# 9                          problem çöz yetenek sahip
# 10                             i̇ş teslim tarih uyan
# 11                   program gereksinim karşıla emin
# 12           yeni yazılım ürün üzeri çeşit test yürü
# 13    bulun hata tür sorun çöz at adım özetle rapo...
# 14                           hata potansiyel tanımla
# 15        risk değerlendir yeni yazılım tamamla önce
# 16     sorun çöz yazılım geliş iş birlik içeri çalış
# 17                 yazılım test metodojilerine hakim
# 18
# 19                                        üniversite
# 20                               bilgisayar mühendis
# 21                                  yazılım mühendis
# 22    yıl yazılım geliş deneyim yazılım geliş dene...
# 23                                        SPCL70SPCL
# 24                                        SPCL43SPCL
# 25                                   SPCL45SPCL core
# 26                                  entity framework
# 27                                        SPCL36SPCL
# 28                                           web api
# 29                                               wcf
# 30                                               soa
# 31                      design patterns konu tecrübe
# 32                                        SPCL20SPCL
# 33                                 SPCL24SPCL script
# 34                                            jquery
# 35                                         angularjs
# 36                             ajax konu bilgi sahip
# 37               web servis entegrasyon konu tecrübe
# 38    ms sql server veri taban biri programla dene...
# 39              nesne yönelim programla konu tecrübe
# 40            kod güvenlik kodla standart konu bilgi
# 41                                    analitik düşün
# 42                                        çözüm odak
# 43                                   öğren yeni açık
# 44                                 takım çalış yatkı
# 45               erkek aday asker tamamla yıl ertele
# 46   mevcut yürü yeniden geliş iste yazılım proje ...
# 47    oyun geliş oyna hayat felsefe dönüş genç din...
# 48    ekip bünye yer al iste aşağı özellik sahip b...
# 49    SPCL21SPCL 3d oyun geliş konu referans proje...
# 50                    SPCL70SPCL programla dil hakim
# 51                    yazılı mimari oop konu tecrübe
# 52                                        üniversite
# 53              mobil oyun optimizasyon standart bil
# 54                           yaratı pratik çözüm sun
# 55                                takım çalış yatkın
# 56                        i̇yi derece i̇ngilizce bil
# 57               asker ilişki bulun erkek aday i̇çin
# 58                    eş zaman birden proje görev al
# 59                                   proje fikir kat

# %%
sentences_split.to_csv("yazilim_uzmani_sentences_v3_split.csv")

# %%
sentences_split.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27835 entries, 0 to 27834
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   index       27835 non-null  int64
#  1   PostId      27835 non-null  object
#  2   SentenceId  27835 non-null  object
#  3   Skill       27835 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 870.0+ KB

# %%
sentences_split["Skill"].value_counts().head(60)
# Out:
#                                                            536
#  css                                                       294
#  SPCL24SPCL script                                         216
#  jquery                                                    191
#  SPCL20SPCL                                                188
#   SPCL20SPCL                                               173
#   üniversite bilgisayar mühendis                           121
#   üniversite                                               119
#   takım çalış yatkın                                       116
#  json                                                      105
#  xml                                                        97
#  ajax                                                       96
#   analitik düşün                                            89
#   erkek aday asker tamamla                                  83
#  SPCL36SPCL                                                 82
#   ekip çalış yatkın                                         80
#  bootstrap                                                  76
#  yazılım mühendis                                           75
#   i̇yi derece i̇ngilizce bil                                71
#  SPCL43SPCL                                                 65
#  rest                                                       59
#   SPCL70SPCL                                                58
#  soap                                                       55
#  takım çalış yatkın                                         52
#  SPCL70SPCL                                                 51
#  tasarım                                                    50
#  matematik                                                  46
#  entity framework                                           45
#  git                                                        45
#  detay önem ver                                             43
#  wcf                                                        43
#  yazılım                                                    42
#  vb                                                         42
#  sorumluluk sahip                                           41
#   üniversite bilgisayar                                     41
#  sorumluluk üstlen                                          39
#  ekip çalış yatkın                                          39
#   yazılım geliş proje aktif yer al deneyim sahip            38
#   tercihen proje yönetim iş analiz bilgi tecrübe sahip      38
#   üniversite lisans program biri mezun                      38
#  tercihen mühendis                                          38
#   ehliyet aktif araç kullan                                 38
#  araştır disiplin çalış konu iddia                          38
#   sözlü yazılı i̇ngilizce bilgi sahip                       38
#   SPCL24SPCL script                                         37
#  bilgisayar program                                         37
#   erkek aday asker hizmet tamamla                           36
#  matematik mühendis                                         36
#  SPCL35SPCL SPCL36SPCL                                      34
#   takım çalış yatkı                                         34
#  svn                                                        31
#  analiz                                                     30
#  geliş                                                      30
#  maven                                                      29
#  web api                                                    28
#   SPCL43SPCL                                                28
#  hibernate                                                  28
#  test                                                       27
#  elektrik elektronik mühendis                               27
#  sonuç odak                                                 27
# Name: Skill, dtype: int64

# %% [markdown]
# # MASKING / STEP 10

# %% [markdown]
# ## FOR SOFT SKILLS

# %% [markdown]
# ### Soft Skill Detection

# %%
soft_skill_dictionary = pd.read_excel(os.path.abspath('..')+"/Data/sentence_dictionary.xlsx")
soft_skill_dictionary["Orjinal Cümle"]=soft_skill_dictionary["Orjinal Cümle"].apply(lambda text : re.sub('i', 'i', text))
soft_skill_dictionary.tail()
# Out:
#              Orjinal Cümle                Soft Skill
# 90          önlisans mezun           önlisans mezunu
# 91        aday ara özellik                         -
# 92  takım birlikte hareket  takım çalışmasına yatkın
# 93               bebekolog                         -
# 94                tercihen                         -

# %%
soft_skill_dictionary=dict(soft_skill_dictionary.values)

# %%
soft_skill_dictionary
# Out:
# {'asker': 'askerlik engelinin bulunmaması',
#  'lise mezun': 'lise mezunu',
#  'üniversite mezun': 'üniversite mezunu',
#  'ingilizce': 'ingilizce',
#  'takım çalış': 'takım çalışmasına yatkın',
#  'ms office': 'ms office',
#  'seyahat engel ': 'seyahat engeli olmayan',
#  'ekip çalış ': 'ekip çalışmasına yatkın',
#  'esnek çalış ': 'esnek çalışma saatlerine uyum sağlayabilen',
#  'aktif araç': 'aktif araç kullanan',
#  'diksiyon ': 'diksiyonu düzgün',
#  'vardiya çalış': 'vardiyalı çalışabilecek',
#  'lisans mezun': 'lisans mezunu',
#  'üniversite lisans': 'lisans mezunu',
#  'analitik düşün': 'analitik düşünebilen',
#  'i̇letişim beceri': 'İletişim becerisi',
#  'yoğun iş tempo ': 'yoğun iş temposuna ayak uydurabilen',
#  'yoğun çalış tempo ': 'yoğun iş temposuna ayak uydurabilen',
#  'i̇nsan ilişki başarı': 'İletişim becerisi',
#  'sorumluluk sahip': 'sorumluluk sahibi',
#  'i̇kna kabiliyet': 'ikna kabiliyeti yüksek',
#  'mühendis bölüm mezun': 'üniversite mezunu',
#  'vardiya sistem çalış': 'vardiyalı çalışabilecek',
#  'dış görün': 'dış görünümüne özen gösteren',
#  'i̇letişimi kuvvet': 'İletişim becerisi',
#  'b sınıf': 'b sınıf ehliyet',
#  'planla organizasyon': 'planlama',
#  'i̇nsan ilişki kuvvet': 'İletişim becerisi',
#  'microsoft office': 'ms office',
#  'üniversite': 'üniversite mezunu',
#  'sigara kullan': 'sigara kullanmayan',
#  'müşteri mutlu': 'müşteri memnuniyetini sağlayabilen',
#  'müşteri memnuniyet': 'müşteri memnuniyetini sağlayabilen',
#  'teknik resim': 'teknik resim',
#  'prezantabl': 'prezantabl',
#  'müşteri odak': 'müşteri odaklı',
#  'dış görünüm': 'dış görünümüne özen gösteren',
#  'güler yüz': 'güler yüzlü',
#  'ikamet': '-',
#  'raporla yap': 'raporlama yapabilen',
#  'çözüm odak': 'çözüm odaklı',
#  'bay bayan': '-',
#  'sonuç odak': 'sonuç odaklı',
#  'tek düzen hesap': 'Tek düzen hesap planlaması',
#  'kişisel bakım özen göster': 'dış görünümüne özen gösteren',
#  'mağazacılık': 'mağazacılık',
#  'hast memnuniyet': 'müşteri odaklı',
#  'şirket sat hedef uyum bireysel hedef gerçek': '-',
#  'şube gün': '-',
#  'benzer pozisyon': 'benzer pozisyonda deyelimli',
#  'prezentabl': 'prezantabl',
#  'motivasyon yüksek': 'motivasyonu yüksek',
#  'müşteri ihtiyaç': 'müşteri odaklı',
#  'sat odak çalış': 'satış odaklı çalışabilen',
#  'problem çöz': 'problem çözme yeteneğine sahip',
#  'öğren gel açık': 'öğrenmeye açık',
#  'iş analiz': 'iş analizi',
#  'yazılım geliş': 'yazılım geliştirme',
#  'i̇ş takip': 'iş analizi',
#  'sağlık uluslararası standart   uzman hekim kadro   has odak üst hizmet anlayış benimse mlpcare sağlık grub   joint commission international j akreditasyon belge sahip hastane türkiye yan yeni yatırım yaygın artır devam et': '-',
#  'sorumluluk al': 'sorumluluk sahibi',
#  'vardiya düzen çalış': 'vardiyalı çalışabilecek',
#  'diksiyon': 'diksiyon düzgün ',
#  'i̇nsan ilişki güç': 'İletişim becerisi',
#  'yoğun çalış': 'yoğun çalışma saatlerine uyum sağlayabilen',
#  'nezaket': 'nezaketli',
#  'pozitif enerji': 'enerjik',
#  'sözlü yazılı iletişim beceri yüksek': 'İletişim becerisi',
#  'teknoloji etkin': 'teknolojiyi etkin kullanabilen ',
#  'i̇letişim yetenek': 'İletişim becerisi',
#  'yazılı sözlü iletişim': 'İletişim becerisi',
#  'office program': 'ms office',
#  'enerjik': 'enerjik',
#  'i̇letişim güç': 'İletişim becerisi',
#  'sat beceri': 'satış becerisi',
#  'mlpcare   il   coğrafi bölge hastane bin yakın çalış sağlık sektör yön ver büyük sağlık kurum': '-',
#  'aş aile üye i̇stanbul genel müdür   ankara   antalya   bursa   i̇zmir şube adana   gaziantep   eskişehir   denizli bölge ofis': '-',
#  'ofis program hakim': 'ms office',
#  'lise denk okul mezun': 'lise mezunu',
#  'i̇nsan kaynak istihdam çözüm konu dünya lider adecco   global bak açı lokal ihtiyaç çözümle geniş bilgi birikim müşteri paylaş': '-',
#  'üzeri firma buluş': '-',
#  'bebekoloji': '-',
#  'bebeveyn': '-',
#  'i̇letişim temsil yetenek güç': 'İletişim becerisi',
#  'i̇letişimi güç': 'İletişim becerisi',
#  'özgüven yüksek': 'özgüvenli',
#  'responsibilities': '-',
#  'önlisans mezun': 'önlisans mezunu',
#  'aday ara özellik': '-',
#  'takım birlikte hareket': 'takım çalışmasına yatkın',
#  'bebekolog': '-',
#  'tercihen': '-'}

# %%
def soft_skill_detection(text):
    value = text;
    for k,v in soft_skill_dictionary.items():
        if(k in text):
            return v
    return value

# %%
sentences_split["Skill"] = sentences_split["Skill"].apply(lambda text: soft_skill_detection(text))

# %%
sentences_split["Skill"].value_counts().head(40)
# Out:
# -                                      1100
# yazılım geliştirme                      831
# üniversite mezunu                       699
# askerlik engelinin bulunmaması          619
#                                         536
# takım çalışmasına yatkın                397
# analitik düşünebilen                    332
#  css                                    294
# ekip çalışmasına yatkın                 260
#  SPCL24SPCL script                      216
#  jquery                                 191
#  SPCL20SPCL                             188
#   SPCL20SPCL                            173
# problem çözme yeteneğine sahip          159
# sorumluluk sahibi                       141
#  json                                   105
# sonuç odaklı                             98
#  xml                                     97
#  ajax                                    96
#  SPCL36SPCL                              82
#  bootstrap                               76
#  yazılım mühendis                        75
# seyahat engeli olmayan                   72
#   i̇yi derece i̇ngilizce bil             71
# lisans mezunu                            71
# çözüm odaklı                             70
#  SPCL43SPCL                              65
# İletişim becerisi                        64
# yoğun iş temposuna ayak uydurabilen      64
#  rest                                    59
#   SPCL70SPCL                             58
#  soap                                    55
# ingilizce                                54
#  SPCL70SPCL                              51
# iş analizi                               51
#  tasarım                                 50
# aktif araç kullanan                      50
# müşteri odaklı                           48
#  matematik                               46
#  git                                     45
# Name: Skill, dtype: int64

# %% [markdown]
# ### CREATE DICTIONARY

# %%
soft_skill_mask = {}
reversed_soft_skill_mask = {}
line_counter=1
for k,v in soft_skill_dictionary.items():
    soft_skill_mask[v] = "SFT"+str(line_counter)+"SFT"
    reversed_soft_skill_mask["SFT"+str(line_counter)+"SFT"] = v
    line_counter +=1

# %%
soft_skill_mask
# Out:
# {'askerlik engelinin bulunmaması': 'SFT1SFT',
#  'lise mezunu': 'SFT79SFT',
#  'üniversite mezunu': 'SFT30SFT',
#  'ingilizce': 'SFT4SFT',
#  'takım çalışmasına yatkın': 'SFT90SFT',
#  'ms office': 'SFT78SFT',
#  'seyahat engeli olmayan': 'SFT7SFT',
#  'ekip çalışmasına yatkın': 'SFT8SFT',
#  'esnek çalışma saatlerine uyum sağlayabilen': 'SFT9SFT',
#  'aktif araç kullanan': 'SFT10SFT',
#  'diksiyonu düzgün': 'SFT11SFT',
#  'vardiyalı çalışabilecek': 'SFT62SFT',
#  'lisans mezunu': 'SFT14SFT',
#  'analitik düşünebilen': 'SFT15SFT',
#  'İletişim becerisi': 'SFT85SFT',
#  'yoğun iş temposuna ayak uydurabilen': 'SFT18SFT',
#  'sorumluluk sahibi': 'SFT61SFT',
#  'ikna kabiliyeti yüksek': 'SFT21SFT',
#  'dış görünümüne özen gösteren': 'SFT45SFT',
#  'b sınıf ehliyet': 'SFT26SFT',
#  'planlama': 'SFT27SFT',
#  'sigara kullanmayan': 'SFT31SFT',
#  'müşteri memnuniyetini sağlayabilen': 'SFT33SFT',
#  'teknik resim': 'SFT34SFT',
#  'prezantabl': 'SFT51SFT',
#  'müşteri odaklı': 'SFT53SFT',
#  'güler yüzlü': 'SFT38SFT',
#  '-': 'SFT92SFT',
#  'raporlama yapabilen': 'SFT40SFT',
#  'çözüm odaklı': 'SFT41SFT',
#  'sonuç odaklı': 'SFT43SFT',
#  'Tek düzen hesap planlaması': 'SFT44SFT',
#  'mağazacılık': 'SFT46SFT',
#  'benzer pozisyonda deyelimli': 'SFT50SFT',
#  'motivasyonu yüksek': 'SFT52SFT',
#  'satış odaklı çalışabilen': 'SFT54SFT',
#  'problem çözme yeteneğine sahip': 'SFT55SFT',
#  'öğrenmeye açık': 'SFT56SFT',
#  'iş analizi': 'SFT59SFT',
#  'yazılım geliştirme': 'SFT58SFT',
#  'diksiyon düzgün ': 'SFT63SFT',
#  'yoğun çalışma saatlerine uyum sağlayabilen': 'SFT65SFT',
#  'nezaketli': 'SFT66SFT',
#  'enerjik': 'SFT73SFT',
#  'teknolojiyi etkin kullanabilen ': 'SFT69SFT',
#  'satış becerisi': 'SFT75SFT',
#  'özgüvenli': 'SFT86SFT',
#  'önlisans mezunu': 'SFT88SFT'}

# %% [markdown]
# ### MASKING

# %%
for key,val in soft_skill_mask.items():
    sentences_split["Skill"] = sentences_split["Skill"].apply(lambda text: text.replace(key," "+val+" "))

# %%
sentences_split["Skill"].value_counts().head(60)
# Out:
#  SFT92SFT                                 1100
#  SFT58SFT                                  831
#  SFT30SFT                                  699
#  SFT1SFT                                   619
#                                            536
#  SFT90SFT                                  397
#  SFT15SFT                                  332
#  css                                       294
#  SFT8SFT                                   260
#  SPCL24SPCL script                         216
#  jquery                                    191
#  SPCL20SPCL                                188
#   SPCL20SPCL                               173
#  SFT55SFT                                  159
#  SFT61SFT                                  141
#  json                                      105
#  SFT43SFT                                   98
#  xml                                        97
#  ajax                                       96
#  SPCL36SPCL                                 82
#  bootstrap                                  76
#  yazılım mühendis                           75
#  SFT7SFT                                    72
#   i̇yi derece i̇ngilizce bil                71
#  SFT14SFT                                   71
#  SFT41SFT                                   70
#  SPCL43SPCL                                 65
#  SFT18SFT                                   64
#  SFT85SFT                                   64
#  rest                                       59
#   SPCL70SPCL                                58
#  soap                                       55
#  SFT4SFT                                    54
#  SPCL70SPCL                                 51
#  SFT59SFT                                   51
#  tasarım                                    50
#  SFT10SFT                                   50
#  SFT53SFT                                   48
#  matematik                                  46
#  git                                        45
#  entity framework                           45
#  detay önem ver                             43
#  wcf                                        43
#  yazılım                                    42
#  vb                                         42
#  SFT9SFT                                    41
#  sorumluluk üstlen                          39
#  araştır disiplin çalış konu iddia          38
#   sözlü yazılı i̇ngilizce bilgi sahip       38
#  bilgisayar program                         37
#   SPCL24SPCL script                         37
#  matematik mühendis                         36
#  SPCL35SPCL SPCL36SPCL                      34
#  svn                                        31
#  analiz                                     30
#  geliş                                      30
#  maven                                      29
#   SPCL43SPCL                                28
#  web api                                    28
#  hibernate                                  28
# Name: Skill, dtype: int64

# %%
sentences_split.to_csv("yazilim_uzmani_sentences_v3_split.csv")

# %% [markdown]
# # CREATE NEW SKILLS DF WITH SPLIT (" ")/ STEP 11

# %%
sentences_split_2 = pd.DataFrame(columns=['PostId','SentenceId' ,'Skill'])

# %%
sentences_split["Skill"]=sentences_split["Skill"].apply(lambda text: re.split(" ",str(text)))

# %%
sentences_split["Skill"]
# Out:
# 0                                      [, , dünya, ülke, ]
# 1                                [, fark, dil, yaklaşık, ]
# 2        [, , firma, kullan, erp, yazılım, SPCL38SPCL, ...
# 3                                           [, SFT14SFT, ]
# 4                [, , erp, pojelerinde, test, uzman, ol, ]
#                                ...
# 27830                                       [, SFT15SFT, ]
# 27831                             [, sorumluluk, üstlen, ]
# 27832                               [, detay, önem, ver, ]
# 27833                                        [, SFT8SFT, ]
# 27834          [, araştır, disiplin, çalış, konu, iddia, ]
# Name: Skill, Length: 27835, dtype: object

# %%
sentences_split=sentences_split.reset_index()

# %%
sentences_split = sentences_split.drop(["level_0"],axis=1)

# %%
sentences_split
# Out:
#        index    PostId     SentenceId  \
# 0          0     Post0      Sentence0
# 1          1     Post0      Sentence0
# 2          2     Post0      Sentence1
# 3          3     Post0      Sentence2
# 4          4     Post0      Sentence3
# ...      ...       ...            ...
# 27830  34854  Post1119  Sentence14269
# 27831  34855  Post1119  Sentence14269
# 27832  34856  Post1119  Sentence14269
# 27833  34858  Post1119  Sentence14270
# 27834  34859  Post1119  Sentence14270
#
#                                                    Skill
# 0                                    [, , dünya, ülke, ]
# 1                              [, fark, dil, yaklaşık, ]
# 2      [, , firma, kullan, erp, yazılım, SPCL38SPCL, ...
# 3                                         [, SFT14SFT, ]
# 4              [, , erp, pojelerinde, test, uzman, ol, ]
# ...                                                  ...
# 27830                                     [, SFT15SFT, ]
# 27831                           [, sorumluluk, üstlen, ]
# 27832                             [, detay, önem, ver, ]
# 27833                                      [, SFT8SFT, ]
# 27834        [, araştır, disiplin, çalış, konu, iddia, ]
#
# [27835 rows x 4 columns]

# %%
for i in range(len(sentences_split)):
    for j in range (len(sentences_split["Skill"][i])):
        sentences_split_2.loc[len(sentences_split_2.index)] = [sentences_split["PostId"][i],sentences_split["SentenceId"][i], sentences_split["Skill"][i][j]] 
sentences_split_2.head()
# Out:
#   PostId SentenceId  Skill
# 0  Post0  Sentence0
# 1  Post0  Sentence0
# 2  Post0  Sentence0  dünya
# 3  Post0  Sentence0   ülke
# 4  Post0  Sentence0

# %%
sentences_split_2.tail()
# Out:
#           PostId     SentenceId     Skill
# 168520  Post1119  Sentence14270  disiplin
# 168521  Post1119  Sentence14270     çalış
# 168522  Post1119  Sentence14270      konu
# 168523  Post1119  Sentence14270     iddia
# 168524  Post1119  Sentence14270

# %%
sentences_split_2.drop(sentences_split_2[sentences_split_2['Skill'] == " "].index, inplace = True)

# %%
sentences_split_2.drop(sentences_split_2[sentences_split_2['Skill'] == ""].index, inplace = True)
sentences_split_2.reset_index(inplace=True)

# %%
sentences_split_2.head(60)
# Out:
#     index PostId  SentenceId        Skill
# 0       2  Post0   Sentence0        dünya
# 1       3  Post0   Sentence0         ülke
# 2       6  Post0   Sentence0         fark
# 3       7  Post0   Sentence0          dil
# 4       8  Post0   Sentence0     yaklaşık
# 5      12  Post0   Sentence1        firma
# 6      13  Post0   Sentence1       kullan
# 7      14  Post0   Sentence1          erp
# 8      15  Post0   Sentence1      yazılım
# 9      16  Post0   Sentence1   SPCL38SPCL
# 10     17  Post0   Sentence1     business
# 11     18  Post0   Sentence1          one
# 12     19  Post0   Sentence1   SPCL29SPCL
# 13     20  Post0   Sentence1           ld
# 14     21  Post0   Sentence1       seviye
# 15     22  Post0   Sentence1        çözüm
# 16     23  Post0   Sentence1        ortak
# 17     24  Post0   Sentence1        firma
# 18     25  Post0   Sentence1    i̇stanbul
# 19     26  Post0   Sentence1       merkez
# 20     27  Post0   Sentence1         ofis
# 21     28  Post0   Sentence1        görev
# 22     29  Post0   Sentence1      yazılım
# 23     30  Post0   Sentence1         test
# 24     31  Post0   Sentence1        uzman
# 25     32  Post0   Sentence1          ara
# 26     35  Post0   Sentence2     SFT14SFT
# 27     39  Post0   Sentence3          erp
# 28     40  Post0   Sentence3  pojelerinde
# 29     41  Post0   Sentence3         test
# 30     42  Post0   Sentence3        uzman
# 31     43  Post0   Sentence3           ol
# 32     47  Post0   Sentence4     analitik
# 33     48  Post0   Sentence4    matematik
# 34     49  Post0   Sentence4        düşün
# 35     50  Post0   Sentence4          yön
# 36     51  Post0   Sentence4       kuvvet
# 37     55  Post0   Sentence5        detay
# 38     56  Post0   Sentence5         odak
# 39     57  Post0   Sentence5        çalış
# 40     60  Post0   Sentence6     SFT40SFT
# 41     63  Post0   Sentence7      SFT8SFT
# 42     66  Post0   Sentence8     SFT55SFT
# 43     70  Post0   Sentence9          i̇ş
# 44     71  Post0   Sentence9       teslim
# 45     72  Post0   Sentence9        tarih
# 46     73  Post0   Sentence9         uyan
# 47     77  Post0  Sentence10      program
# 48     78  Post0  Sentence10   gereksinim
# 49     79  Post0  Sentence10      karşıla
# 50     80  Post0  Sentence10         emin
# 51     83  Post0  Sentence10         yeni
# 52     84  Post0  Sentence10      yazılım
# 53     85  Post0  Sentence10         ürün
# 54     86  Post0  Sentence10        üzeri
# 55     87  Post0  Sentence10        çeşit
# 56     88  Post0  Sentence10         test
# 57     89  Post0  Sentence10         yürü
# 58     93  Post0  Sentence11        bulun
# 59     94  Post0  Sentence11         hata

# %%
sentences_split_2.to_csv("yazilim_uzmani_sentences_v4_split.csv")

# %%
sentences_split_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102344 entries, 0 to 102343
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   index       102344 non-null  int64
#  1   PostId      102344 non-null  object
#  2   SentenceId  102344 non-null  object
#  3   Skill       102344 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 3.1+ MB

# %%
sentences_split_2["Skill"].value_counts().head(60)
# Out:
# konu          2307
# sahip         2158
# geliş         2072
# bilgi         1893
# yazılım       1498
# uygula        1355
# ol            1322
# proje         1229
# web           1185
# deneyim       1141
# SFT92SFT      1126
# tecrübe       1109
# teknoloji     1092
# çalış         1050
# SPCL24SPCL     867
# SFT58SFT       831
# hakim          743
# kullan         730
# SFT30SFT       699
# yap            678
# al             623
# SFT1SFT        619
# tasarım        598
# bil            589
# SPCL20SPCL     577
# yeni           572
# sistem         548
# script         545
# et             542
# görev          531
# css            515
# i̇ngilizce     510
# uzman          485
# sql            477
# servis         467
# ara            445
# programla      429
# takip          427
# mühendis       414
# SPCL70SPCL     412
# SPCL36SPCL     408
# derece         405
# ver            402
# süreç          399
# SFT90SFT       397
# dil            396
# SPCL45SPCL     392
# test           387
# jquery         386
# kod            377
# taban          370
# hak            369
# çözüm          366
# framework      358
# teknik         355
# geliştir       351
# iş             344
# sağla          336
# ekip           335
# i̇yi           332
# Name: Skill, dtype: int64

# %% [markdown]
# # CLEAN VERBS / STEP 12

# %% [markdown]
# Kökü fiil olan kelimelerin temizlenmesi

# %%
sentences_split = pd.read_csv("yazilim_uzmani_sentences_v4_split.csv")
sentences_split = sentences_split.drop(["Unnamed: 0","index"],axis=1)

# %%
sentences_split.drop(sentences_split[sentences_split['Skill'] == " "].index, inplace = True)

# %%
sentences_split.drop(sentences_split[sentences_split['Skill'] == ""].index, inplace = True)
sentences_split.reset_index(inplace=True)
sentences_split=sentences_split.drop("index",axis=1)
sentences_split
# Out:
#           PostId     SentenceId     Skill
# 0          Post0      Sentence0     dünya
# 1          Post0      Sentence0      ülke
# 2          Post0      Sentence0      fark
# 3          Post0      Sentence0       dil
# 4          Post0      Sentence0  yaklaşık
# ...          ...            ...       ...
# 102339  Post1119  Sentence14270   araştır
# 102340  Post1119  Sentence14270  disiplin
# 102341  Post1119  Sentence14270     çalış
# 102342  Post1119  Sentence14270      konu
# 102343  Post1119  Sentence14270     iddia
#
# [102344 rows x 3 columns]

# %%
sentences_split["Skill"]=sentences_split["Skill"].apply(lambda text : re.sub('i̇', 'i', text))

# %%
def clean_verbs(text):
    stem_text=text
    analysis: jpype.java.util.ArrayList = (
    morphology.analyzeAndDisambiguate(text).bestAnalysis()
    )
    for i in analysis:
        if ("UNK" in  str(i.getLemmas()[0])) :
            stem_text=str(i.getStem())
        else:
            stem_text = " "
    return stem_text

# %%
clean_verbs("i̇yi")
# Out:
# 'i̇yi'

# %%
sentences_split["Skill"]=sentences_split["Skill"].apply(lambda text: clean_verbs(str(text)))

# %%
sentences_split["Skill"]
# Out:
# 0
# 1
# 2
# 3
# 4
#          ..
# 102339
# 102340
# 102341
# 102342
# 102343
# Name: Skill, Length: 102344, dtype: object

# %%
sentences_split.drop(sentences_split[sentences_split['Skill'] == " "].index, inplace = True)
sentences_split.drop(sentences_split[sentences_split['Skill'] == ""].index, inplace = True)
sentences_split.drop(sentences_split[sentences_split['Skill'] == "'"].index, inplace = True)
sentences_split.drop(sentences_split[sentences_split['Skill'] == "i"].index, inplace = True)
sentences_split.drop(sentences_split[sentences_split['Skill'] == "ld"].index, inplace = True)
sentences_split.drop(sentences_split[sentences_split['Skill'] == "yr"].index, inplace = True)

# %%
sentences_split
# Out:
#           PostId     SentenceId       Skill
# 7          Post0      Sentence1         erp
# 9          Post0      Sentence1  SPCL38SPCL
# 12         Post0      Sentence1  SPCL29SPCL
# 26         Post0      Sentence2    SFT14SFT
# 27         Post0      Sentence3         erp
# ...          ...            ...         ...
# 102324  Post1119  Sentence14266    SFT14SFT
# 102325  Post1119  Sentence14266    SFT92SFT
# 102331  Post1119  Sentence14268     SFT1SFT
# 102332  Post1119  Sentence14269    SFT15SFT
# 102338  Post1119  Sentence14270     SFT8SFT
#
# [22246 rows x 3 columns]

# %%
sentences_split["Skill"].value_counts().to_csv("yazilim_uzmani_skills.csv")

# %% [markdown]
# ### CLEAN IRRELEVANT THINGS

# %%
sentences_split["Skill"]=sentences_split["Skill"].replace(to_replace=["'|§|\||>|²|¦"],value=" ",regex=True,inplace=False)
sentences_split["Skill"]=sentences_split["Skill"].str.replace(r'\\'," ")

# %% [markdown]
# # REVERSED MASKING / STEP 13

# %% [markdown]
# Maskelenen tüm skillerin geri alınması

# %% [markdown]
# ### SPECIAL SKILLS

# %%
special_terms_dictionary = {}
reversed_special_terms_dictionary = {}
with open(os.path.abspath('..')+"/Data/_special_terms.txt",encoding="utf8") as file:
    line_counter=1
    for line in file:
        line=line.lower()
        special_terms_dictionary[line.strip("\n")] = "SPCL"+str(line_counter)+"SPCL"
        reversed_special_terms_dictionary["SPCL"+str(line_counter)+"SPCL"] = line.strip()
        line_counter +=1

# %%
for key,val in reversed_special_terms_dictionary.items():
    sentences_split["Skill"] = sentences_split["Skill"].apply(lambda text: text.replace(key,val))

# %% [markdown]
# ### SOFT SKILLS

# %%
soft_skill_mask = {}
reversed_soft_skill_mask = {}
line_counter=1
for k,v in soft_skill_dictionary.items():
    soft_skill_mask[v] = "SFT"+str(line_counter)+"SFT"
    reversed_soft_skill_mask["SFT"+str(line_counter)+"SFT"] = v
    line_counter +=1

# %%
for key,val in reversed_soft_skill_mask.items():
    sentences_split["Skill"] = sentences_split["Skill"].apply(lambda text: text.replace(key,val))

# %%
sentences_split["Skill"]=sentences_split["Skill"].replace(to_replace=["-"],value=" ",regex=True,inplace=False)
sentences_split.drop(sentences_split[sentences_split['Skill'] == " "].index, inplace = True)

# %%
sentences_split["Skill"].value_counts().head(60)
# Out:
# java                                   867
# yazılım geliştirme                     831
# üniversite mezunu                      699
# askerlik engelinin bulunmaması         619
# html                                   577
# css                                    515
# sql                                    477
# c#                                     412
# mvc                                    408
# takım çalışmasına yatkın               397
# .net                                   392
# jquery                                 386
# asp.net                                377
# analitik düşünebilen                   332
# api                                    302
# ekip çalışmasına yatkın                260
# go                                     257
# php                                    234
# json                                   217
# xml                                    212
# soap                                   207
# problem çözme yeteneğine sahip         159
# bootstrap                              157
# entity                                 157
# restful                                143
# sorumluluk sahibi                      141
# angular                                134
# oriented                               132
# js                                     132
# object                                 131
# android                                130
# oop                                    130
# react                                  128
# t sql                                  115
# ios                                    113
# sonuç odaklı                            98
# erp                                     96
# tfs                                     94
# responsive                              94
# pl/sql                                  81
# svn                                     78
# wcf                                     74
# hibernate                               73
# scrum                                   73
# agile                                   72
# seyahat engeli olmayan                  72
# lisans mezunu                           71
# çözüm odaklı                            70
# knowledge                               70
# e ticaret                               67
# ui                                      66
# angularjs                               65
# procedure                               65
# İletişim becerisi                       64
# yoğun iş temposuna ayak uydurabilen     64
# ar ge                                   61
# orm                                     60
# stored                                  57
# patterns                                56
# linq                                    56
# Name: Skill, dtype: int64

# %% [markdown]
# # REPLACE FOR "YAZILIM UZMANI" SKILLS

# %% [markdown]
# Sadece yazılım uzmanı için yapılacak olran ara işlemdir. Diğer pozisyonlar için bu işlemin yapılmasına gerek yok.

# %%
sentences_split["Skill"]=sentences_split["Skill"].str.replace("restfull","restful")
sentences_split["Skill"]=sentences_split["Skill"].str.replace("object\soriented","oop",regex=True)
sentences_split["Skill"]=sentences_split["Skill"].str.replace("(?:^|\W)object(?:$|\W)","oop",regex=True)
sentences_split["Skill"]=sentences_split["Skill"].str.replace("asp.*","asp.net",regex=True)
sentences_split["Skill"]=sentences_split["Skill"].str.replace("uuml","uml")
sentences_split["Skill"]=sentences_split["Skill"].str.replace("önyüz","frontend")
sentences_split["Skill"]=sentences_split["Skill"].str.replace("ritma.*","ritma",regex=True)
sentences_split["Skill"]=sentences_split["Skill"].str.replace("bootsrap","bootstrap")
sentences_split["Skill"]=sentences_split["Skill"].str.replace("plsql","pg/sql")
sentences_split["Skill"]=sentences_split["Skill"].str.replace("apis","api")
sentences_split["Skill"]=sentences_split["Skill"].str.replace("mikroservis","microservices")
sentences_split["Skill"]=sentences_split["Skill"].str.replace("nodejs","node.js")
sentences_split["Skill"]=sentences_split["Skill"].str.replace("entity.*","entityframework",regex=True)
sentences_split["Skill"]=sentences_split["Skill"].str.replace("fullstack","full stack")
sentences_split["Skill"]=sentences_split["Skill"].str.replace("backend","back end")
sentences_split["Skill"]=sentences_split["Skill"].str.replace("frontend","front end")

# %% [markdown]
# # CLEANING LOW FREQUENCY SKIILS / STEP 14

# %%
sentences_split=sentences_split.groupby('Skill').filter(lambda x : len(x)>11)
sentences_split.reset_index(inplace=True)

# %%
sentences_split
# Out:
#         index    PostId     SentenceId                           Skill
# 0           7     Post0      Sentence1                             erp
# 1           9     Post0      Sentence1                             sap
# 2          12     Post0      Sentence1                              go
# 3          26     Post0      Sentence2                   lisans mezunu
# 4          27     Post0      Sentence3                             erp
# ...       ...       ...            ...                             ...
# 16334  102323  Post1119  Sentence14265             aktif araç kullanan
# 16335  102324  Post1119  Sentence14266                   lisans mezunu
# 16336  102331  Post1119  Sentence14268  askerlik engelinin bulunmaması
# 16337  102332  Post1119  Sentence14269            analitik düşünebilen
# 16338  102338  Post1119  Sentence14270         ekip çalışmasına yatkın
#
# [16339 rows x 4 columns]

# %%
sentences_split=sentences_split.drop_duplicates()

# %%
sentences_split.to_csv("yazilim_uzmani_skills_v2.csv")
sentences_split["Skill"].value_counts().to_csv("yazilim_uzmani_skills_counts_v1.csv")
